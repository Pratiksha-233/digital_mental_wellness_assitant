# %% [markdown]
# ## imports and setup

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.models import Sequential, model_from_json
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, BatchNormalization
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
# %matplotlib inline

# %% [markdown]
# ## data paths

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/validation'

# %% [markdown]
# ## create dataframe from directory

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir, label)):
            image_paths.append(os.path.join(dir, label, imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths, labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
print("Training data:")
print(train.head())
print("\nTraining data distribution:")
print(train['label'].value_counts())

test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
print("\nValidation data:")
print(test.head())
print("\nValidation data distribution:")
print(test['label'].value_counts())
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed
# Training data:
#                           image  label
# 0      images/train\angry\0.jpg  angry
# 1      images/train\angry\1.jpg  angry
# 2     images/train\angry\10.jpg  angry
# 3  images/train\angry\10002.jpg  angry
# 4  images/train\angry\10016.jpg  angry
#
# Training data distribution:
# label
# happy       7164
# neutral     4982
# sad         4938
# fear        4103
# angry       3993
# surprise    3205
# disgust      436
# Name: count, dtype: int64
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed
#
# Validation data:
#                                image  label
# 0  images/validation\angry\10052.jpg  angry
# 1  images/validation\angry\10065.jpg  angry
# 2  images/validation\angry\10079.jpg  angry
# 3  images/validation\angry\10095.jpg  angry
# ...

# %%
train.head()
test.head()
train.info()
train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28821 entries, 0 to 28820
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   28821 non-null  object
#  1   label   28821 non-null  object
# dtypes: object(2)
# memory usage: 450.5+ KB
#                                  image  label
# count                            28821  28821
# unique                           28821      7
# top     images/train\surprise\9996.jpg  happy
# freq                                 1   7164

# %%
train['label'].value_counts()
# Out:
# label
# happy       7164
# neutral     4982
# sad         4938
# fear        4103
# angry       3993
# surprise    3205
# disgust      436
# Name: count, dtype: int64

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train['label_encoded']),
    y=df['label_encoded']
)

class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label_encoded'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 6
# ...

# %% [markdown]
# ## extract features

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, color_mode='grayscale')
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
print("\nExtracting training features...")
train_features = extract_features(train['image'])

print("Extracting validation features...")
test_features = extract_features(test['image'])
# Out:
# Extracting training features...
# 100%|█████████████| 28821/28821 [00:18<00:00, 1523.58it/s]
# Extracting validation features...
# 100%|███████████████| 7066/7066 [00:04<00:00, 1748.61it/s]

# %% [markdown]
# ## normalize data

# %%
x_train = train_features / 255.0
x_test = test_features / 255.0

print(f"Training data shape: {x_train.shape}")
print(f"Validation data shape: {x_test.shape}")
# Out:
# Training data shape: (28821, 48, 48, 1)
# Validation data shape: (7066, 48, 48, 1)

# %% [markdown]
# ## encode labels

# %%
le = LabelEncoder()
le.fit(train['label'])

y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# Convert to categorical
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

print(f"Training labels shape: {y_train.shape}")
print(f"Validation labels shape: {y_test.shape}")
# Out:
# Training labels shape: (28821, 7)
# Validation labels shape: (7066, 7)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train['label_encoded']),
    y=df['label_encoded']
)

class_weights = dict(enumerate(class_weights))
class_weights
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label_encoded'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 6
# ...

# %% [markdown]
# ## CNN model

# %%
model = Sequential()

# Block 1
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Block 2
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Block 3
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Block 4 (NEW - Increased capacity)
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

# Classifier
model.add(Flatten())
model.add(Dense(256, activation='relu'))  # Increased from 128 to 256
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))  # NEW - Additional dense layer
model.add(Dropout(0.5))
model.add(Dense(len(le.classes_), activation='softmax'))

model.summary()
# Out:
# C:\Users\attar\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Layer (type)          ┃ Output Shape     ┃  Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ conv2d (Conv2D)       │ (None, 48, 48,   │      320 │
# │                       │ 32)              │          │
# ├───────────────────────┼──────────────────┼──────────┤
# │ batch_normalization   │ (None, 48, 48,   │      128 │
# │ (BatchNormalization)  │ 32)              │          │
# ├───────────────────────┼──────────────────┼──────────┤
# │ max_pooling2d         │ (None, 24, 24,   │        0 │
# ...

# %% [markdown]
# ## compile model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## data augumentation

# %%
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    fill_mode='nearest'
)

# %% [markdown]
# ## call backs

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
]

# %% [markdown]
# ## train model with augumentation

# %%
history = model.fit(
    train_datagen.flow(x_train, y_train, batch_size=128),
    batch_size=128,
    epochs=50,
    validation_data=(x_test, y_test),
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 146s 643ms/step - accuracy: 0.3941 - loss: 1.5618 - val_accuracy: 0.4352 - val_loss: 1.4582 - learning_rate: 0.0010
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 139s 614ms/step - accuracy: 0.4066 - loss: 1.5281 - val_accuracy: 0.4761 - val_loss: 1.3657 - learning_rate: 0.0010
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 137s 603ms/step - accuracy: 0.4244 - loss: 1.4973 - val_accuracy: 0.4744 - val_loss: 1.3527 - learning_rate: 0.0010
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 136s 603ms/step - accuracy: 0.4307 - loss: 1.4709 - val_accuracy: 0.4982 - val_loss: 1.3004 - learning_rate: 0.0010
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 134s 593ms/step - accuracy: 0.4444 - loss: 1.4421 - val_accuracy: 0.5075 - val_loss: 1.2740 - learning_rate: 0.0010
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 134s 594ms/step - accuracy: 0.4559 - loss: 1.4218 - val_accuracy: 0.5098 - val_loss: 1.2379 - learning_rate: 0.0010
# Epoch 7/50
# ...

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## evaluate model

# %%
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

print("\n" + "="*60)
print("CLASSIFICATION REPORT")
print("="*60)
print(classification_report(y_test_classes, y_pred_classes, 
                          target_names=le.classes_))
# Out:
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
#
# ...
# CLASSIFICATION REPORT
# ...
#               precision    recall  f1-score   support
#
#        angry       0.50      0.60      0.55       960
#      disgust       0.82      0.29      0.43       111
#         fear       0.57      0.20      0.29      1018
#        happy       0.83      0.88      0.85      1825
#      neutral       0.50      0.76      0.60      1216
#          sad       0.55      0.42      0.48      1139
#     surprise       0.71      0.77      0.74       797
#
#     accuracy                           0.63      7066
#    macro avg       0.64      0.56      0.56      7066
# weighted avg       0.63      0.63      0.61      7066

# %% [markdown]
# ## confusion matrix

# %%
cm = confusion_matrix(y_test_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## save model

# %%
model_json = model.to_json()
with open("emotiondetecter2.json", 'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetecter2.h5")
print("\nModel saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!

# %% [markdown]
# ## load model for testing

# %%
json_file = open("emotiondetecter2.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetecter2.h5")
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
label = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %% [markdown]
# ## prediction funtion

# %%
def ef(image):
    img = load_img(image, color_mode='grayscale')
    feature = np.array(img)
    feature = feature.reshape(1, 48, 48, 1)
    return feature / 255.0

# %%
# Test 1: Angry
print("\n" + "="*60)
print("TEST 1: ANGRY EMOTION")
print("="*60)
image = 'images/validation/angry/1024.jpg'
print("Original image emotion: angry")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 1: ANGRY EMOTION
# ...
# Original image emotion: angry
# Model prediction: neutral (Confidence: 29.76%)

# %%
# Test 2: Angry (alternative)
print("\n" + "="*60)
print("TEST 2: ANGRY EMOTION (Alternative)")
print("="*60)
image = 'images/validation/angry/2055.jpg'
print("Original image emotion: angry")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 2: ANGRY EMOTION (Alternative)
# ...
# Original image emotion: angry
# Model prediction: angry (Confidence: 23.28%)

# %%
# Test 3: Angry (training data)
print("\n" + "="*60)
print("TEST 3: ANGRY EMOTION (Training Data)")
print("="*60)
image = 'images/train/angry/43.jpg'
print("Original image emotion: angry")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 3: ANGRY EMOTION (Training Data)
# ...
# Original image emotion: angry
# Model prediction: angry (Confidence: 52.51%)

# %%
# Test 4: Fear
print("\n" + "="*60)
print("TEST 4: FEAR EMOTION")
print("="*60)
image = 'images/validation/fear/270.jpg'
print("Original image emotion: fear")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 4: FEAR EMOTION
# ...
# Original image emotion: fear
# Model prediction: angry (Confidence: 43.26%)

# %%
# Test 5: Disgust
print("\n" + "="*60)
print("TEST 5: DISGUST EMOTION")
print("="*60)
image = 'images/validation/disgust/3778.jpg'
print("Original image emotion: disgust")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 5: DISGUST EMOTION
# ...
# Original image emotion: disgust
# Model prediction: angry (Confidence: 58.77%)

# %%
# Test 6: Happy
print("\n" + "="*60)
print("TEST 6: HAPPY EMOTION")
print("="*60)
image = 'images/validation/happy/8.jpg'
print("Original image emotion: happy")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 6: HAPPY EMOTION
# ...
# Original image emotion: happy
# Model prediction: happy (Confidence: 94.97%)

# %%
# Test 7: Surprise
print("\n" + "="*60)
print("TEST 7: SURPRISE EMOTION")
print("="*60)
image = 'images/validation/surprise/435.jpg'
print("Original image emotion: surprise")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 7: SURPRISE EMOTION
# ...
# Original image emotion: surprise
# Model prediction: surprise (Confidence: 85.86%)

# %%
# Test 8: Neutral
print("\n" + "="*60)
print("TEST 8: NEUTRAL EMOTION")
print("="*60)
image = 'images/validation/neutral/405.jpg'
print("Original image emotion: neutral")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 8: NEUTRAL EMOTION
# ...
# Original image emotion: neutral
# Model prediction: neutral (Confidence: 87.59%)

# %%
# Test 9: Sad
print("\n" + "="*60)
print("TEST 9: SAD EMOTION")
print("="*60)
image = 'images/validation/sad/115.jpg'
print("Original image emotion: sad")
img = ef(image)
pred = model.predict(img, verbose=0)
pred_label = label[pred.argmax()]
confidence = pred.max() * 100
print(f"Model prediction: {pred_label} (Confidence: {confidence:.2f}%)")
plt.figure(figsize=(4, 4))
plt.imshow(img.reshape(48, 48), cmap='gray')
plt.title(f"Predicted: {pred_label}")
plt.axis('off')
plt.show()
# Out:
# ...
# TEST 9: SAD EMOTION
# ...
# Original image emotion: sad
# Model prediction: sad (Confidence: 52.18%)
