# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.models import Sequential, model_from_json
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, BatchNormalization
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
# %matplotlib inline

# %%
TRAIN_DIR = 'images/train'
TEST_DIR = 'images/validation'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir, label)):
            image_paths.append(os.path.join(dir, label, imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths, labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
print("Training data:")
print(train.head())
print("\nTraining data distribution:")
print(train['label'].value_counts())

test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
print("\nValidation data:")
print(test.head())
print("\nValidation data distribution:")
print(test['label'].value_counts())
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed
# Training data:
#                           image  label
# 0      images/train\angry\0.jpg  angry
# 1      images/train\angry\1.jpg  angry
# 2     images/train\angry\10.jpg  angry
# 3  images/train\angry\10002.jpg  angry
# 4  images/train\angry\10016.jpg  angry
#
# Training data distribution:
# label
# happy       7164
# neutral     4982
# sad         4938
# fear        4103
# angry       3993
# surprise    3205
# disgust      436
# Name: count, dtype: int64
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed
#
# Validation data:
#                                image  label
# 0  images/validation\angry\10052.jpg  angry
# 1  images/validation\angry\10065.jpg  angry
# 2  images/validation\angry\10079.jpg  angry
# 3  images/validation\angry\10095.jpg  angry
# 4  images/validation\angry\10121.jpg  angry
#
# Validation data distribution:
# label
# happy       1825
# neutral     1216
# sad         1139
# fear        1018
# angry        960
# surprise     797
# disgust      111
# Name: count, dtype: int64

# %%
train['label'] = train['label'].str.lower().str.strip()
print(train['label'].value_counts())
# Out:
# label
# happy       7164
# neutral     4982
# sad         4938
# fear        4103
# angry       3993
# surprise    3205
# disgust      436
# Name: count, dtype: int64

# %%
le = LabelEncoder()
y_train = le.fit_transform(train['label'])
y_val   = le.transform(test['label'])

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)

class_weights = dict(enumerate(class_weights))
print(class_weights)
# Out:
# {0: np.float64(1.031125898894494), 1: np.float64(9.443315858453474), 2: np.float64(1.0034817729187702), 3: np.float64(0.5747188322565207), 4: np.float64(0.8264322991340254), 5: np.float64(0.8337962159347335), 6: np.float64(1.2846445286382884)}

# %%
print(dict(zip(le.classes_, range(len(le.classes_)))))
# Out:
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
import cv2
import numpy as np

IMG_SIZE = 48

def load_image(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
    img = img / 255.0
    return img

# Training images
X_train = np.array(train['image'].apply(load_image).tolist())
X_train = X_train.reshape(-1, 48, 48, 1)

# Validation images
X_val = np.array(test['image'].apply(load_image).tolist())
X_val = X_val.reshape(-1, 48, 48, 1)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

datagen.fit(X_train)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Input(shape=(48, 48, 1)), 

    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    validation_data=(X_val, y_val),
    epochs=30,
    class_weight=class_weights
)
# Out:
# Epoch 1/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 60s 123ms/step - accuracy: 0.1939 - loss: 1.9127 - val_accuracy: 0.2223 - val_loss: 1.8674
# Epoch 2/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 53s 118ms/step - accuracy: 0.2440 - loss: 1.8393 - val_accuracy: 0.3397 - val_loss: 1.7148
# Epoch 3/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 56s 123ms/step - accuracy: 0.2695 - loss: 1.7884 - val_accuracy: 0.2791 - val_loss: 1.7861
# Epoch 4/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 79s 117ms/step - accuracy: 0.2937 - loss: 1.7517 - val_accuracy: 0.3704 - val_loss: 1.6573
# Epoch 5/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 53s 118ms/step - accuracy: 0.3145 - loss: 1.7154 - val_accuracy: 0.3896 - val_loss: 1.5989
# Epoch 6/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 53s 118ms/step - accuracy: 0.3292 - loss: 1.6926 - val_accuracy: 0.4229 - val_loss: 1.5120
# Epoch 7/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 53s 117ms/step - accuracy: 0.3395 - loss: 1.6573 - val_accuracy: 0.3718 - val_loss: 1.6152
# Epoch 8/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - accuracy: 0.3472 - loss: 1.6460 - val_accuracy: 0.4164 - val_loss: 1.5191
# Epoch 9/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 56s 123ms/step - accuracy: 0.3601 - loss: 1.6310 - val_accuracy: 0.4110 - val_loss: 1.5236
# Epoch 10/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 55s 123ms/step - accuracy: 0.3618 - loss: 1.6137 - val_accuracy: 0.4523 - val_loss: 1.4381
# Epoch 11/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 56s 123ms/step - accuracy: 0.3665 - loss: 1.6100 - val_accuracy: 0.4174 - val_loss: 1.5204
# Epoch 12/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - accuracy: 0.3747 - loss: 1.5877 - val_accuracy: 0.4410 - val_loss: 1.4520
# Epoch 13/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 60s 133ms/step - accuracy: 0.3763 - loss: 1.5807 - val_accuracy: 0.4779 - val_loss: 1.3829
# Epoch 14/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - accuracy: 0.3821 - loss: 1.5685 - val_accuracy: 0.4493 - val_loss: 1.4753
# Epoch 15/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 56s 125ms/step - accuracy: 0.3784 - loss: 1.5655 - val_accuracy: 0.4727 - val_loss: 1.3909
# Epoch 16/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.3858 - loss: 1.5589 - val_accuracy: 0.4594 - val_loss: 1.4115
# Epoch 17/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.3884 - loss: 1.5487 - val_accuracy: 0.4523 - val_loss: 1.4358
# Epoch 18/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - accuracy: 0.3978 - loss: 1.5317 - val_accuracy: 0.4758 - val_loss: 1.4025
# Epoch 19/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - accuracy: 0.3975 - loss: 1.5226 - val_accuracy: 0.4714 - val_loss: 1.3922
# Epoch 20/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 55s 121ms/step - accuracy: 0.3993 - loss: 1.5198 - val_accuracy: 0.4741 - val_loss: 1.3961
# Epoch 21/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - accuracy: 0.3980 - loss: 1.5230 - val_accuracy: 0.4781 - val_loss: 1.3681
# Epoch 22/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 78s 118ms/step - accuracy: 0.4034 - loss: 1.5101 - val_accuracy: 0.4761 - val_loss: 1.3819
# Epoch 23/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 55s 122ms/step - accuracy: 0.4049 - loss: 1.5077 - val_accuracy: 0.4540 - val_loss: 1.4148
# Epoch 24/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - accuracy: 0.4049 - loss: 1.5091 - val_accuracy: 0.4769 - val_loss: 1.3711
# Epoch 25/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 54s 119ms/step - accuracy: 0.4081 - loss: 1.5029 - val_accuracy: 0.4666 - val_loss: 1.3970
# Epoch 26/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 55s 122ms/step - accuracy: 0.4071 - loss: 1.4969 - val_accuracy: 0.4738 - val_loss: 1.3917
# Epoch 27/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 56s 124ms/step - accuracy: 0.4154 - loss: 1.4925 - val_accuracy: 0.4977 - val_loss: 1.3070
# Epoch 28/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - accuracy: 0.4073 - loss: 1.4857 - val_accuracy: 0.4653 - val_loss: 1.3929
# Epoch 29/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 54s 120ms/step - accuracy: 0.4116 - loss: 1.4871 - val_accuracy: 0.4853 - val_loss: 1.3580
# Epoch 30/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 56s 123ms/step - accuracy: 0.4129 - loss: 1.4807 - val_accuracy: 0.4925 - val_loss: 1.3343

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test).argmax(axis=1)
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 from sklearn.metrics import classification_report
# ----> 3 y_pred = model.predict(X_test).argmax(axis=1)
#       4 print(classification_report(y_test, y_pred, target_names=le.classes_))
#
# NameError: name 'X_test' is not defined

# %%
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    validation_data=(X_val, y_val),
    epochs=30,
    class_weight=class_weights
)
# Out:
# Epoch 1/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.4128 - loss: 1.4857 - val_accuracy: 0.4883 - val_loss: 1.3399
# Epoch 2/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━
30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 57s 125ms/step - accuracy: 0.4405 - loss: 1.4151 - val_accuracy: 0.4858 - val_loss: 1.3201
# Epoch 28/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 80s 122ms/step - accuracy: 0.4361 - loss: 1.4210 - val_accuracy: 0.5027 - val_loss: 1.3064
# Epoch 29/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 53s 118ms/step - accuracy: 0.4349 - loss: 1.4259 - val_accuracy: 0.5164 - val_loss: 1.2693
# Epoch 30/30
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 53s 117ms/step - accuracy: 0.4379 - loss: 1.4069 - val_accuracy: 0.4885 - val_loss: 1.3268

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
print("Final Training Accuracy:", history.history['accuracy'][-1])
print("Final Validation Accuracy:", history.history['val_accuracy'][-1])
# Out:
# Final Training Accuracy: 0.437909871339798
# Final Validation Accuracy: 0.48853665590286255

# %%
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D,
    BatchNormalization, Flatten,
    Dense, Dropout
)

model = Sequential([
    Input(shape=(48, 48, 1)),

    Conv2D(32, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),

    Dense(7, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# %%
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    validation_data=(X_val, y_val),
    epochs=80,
    class_weight=class_weights,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 102s 208ms/step - accuracy: 0.1399 - loss: 2.0475 - val_accuracy: 0.1261 - val_loss: 1.9211
# Epoch 2/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 92s 203ms/step - accuracy: 0.1418 - loss: 1.9176 - val_accuracy: 0.2382 - val_loss: 1.8384
# Epoch 3/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 93s 205ms/step - accuracy: 0.1670 - loss: 1.8854 - val_accuracy: 0.1995 - val_loss: 1.9292
# Epoch 4/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 93s 207ms/step - accuracy: 0.1890 - loss: 1.8581 - val_accuracy: 0.3115 - val_loss: 1.6987
# Epoch 5/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 143s 208ms/step - accuracy: 0.2177 - loss: 1.8382 - val_accuracy: 0.2297 - val_loss: 1.7947
# Epoch 6/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 94s 207ms/step - accuracy: 0.2447 - loss: 1.8063 - val_accuracy: 0.3314 - val_loss: 1.7109
# Epoch 7/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 92s 203ms/step - accuracy: 0.2666 - loss: 1.7929 - val_accuracy: 0.3555 - val_loss: 1.7160
# Epoch 8/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 91s 202ms/step - accuracy: 0.2798 - loss: 1.7793 - val_accuracy: 0.2765 - val_loss: 1.7723
# Epoch 9/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 93s 205ms/step - accuracy: 0.2931 - loss: 1.7518 - val_accuracy: 0.2829 - val_loss: 1.7719
# Epoch 10/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 95s 210ms/step - accuracy: 0.3134 - loss: 1.7127 - val_accuracy: 0.2519 - val_loss: 1.7951
# Epoch 11/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 94s 209ms/step - accuracy: 0.3192 - loss: 1.6973 - val_accuracy: 0.3790 - val_loss: 1.6402
# Epoch 12/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 94s 208ms/step - accuracy: 0.3428 - loss: 1.6683 - val_accuracy: 0.2055 - val_loss: 1.8512
# Epoch 13/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 331297s 736s/step - accuracy: 0.3434 - loss: 1.6523 - val_accuracy: 0.4232 - val_loss: 1.5492
# Epoch 14/80
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 140s 310ms/step - accuracy: 0.3596 - loss: 1.6298 - val_accuracy: 0.4158 - val_loss: 1.5228
# Epoch 15/80
#   5/451 ━━━━━━━━━━━━━━━━━━━━ 1:28 198ms/step - accuracy: 0.3786 - loss: 1.7267
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 history = model.fit(
#       2     datagen.flow(X_train, y_train, batch_size=64),
#       3     validation_data=(X_val, y_val),
#       4     epochs=80,
#       5     class_weight=class_weights,
#       6     callbacks=[early_stop]
#       7 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
